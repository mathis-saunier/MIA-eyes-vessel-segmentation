# %% [markdown]
# # Prediction

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import yaml

sys.path.append('..')

# Chargement de la configuration
config_path = '../configs/config_unet_512.yaml'
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

print("Configuration chargée:")
print(f"| Modèle: {config['model']['name']} ({config['model']['in_channels']} -> {config['model']['out_channels']})")
# Out:
# Configuration chargée:
# | Modèle: UNet (3 -> 1)

# %% [markdown]
# ## Données

# %%
# Chargement des chemins depuis la config
test_img_path = config['data']['test_img_path']
test_label_path = config['data']['test_label_path']

test_img_files = os.listdir(test_img_path)
test_label_files = os.listdir(test_label_path)

test_img = [os.path.join(test_img_path, file) for file in test_img_files]
test_label = [os.path.join(test_label_path, file) for file in test_label_files]

print(f'Number of testing images: {len(test_img)}')
print(f'Number of testing labels: {len(test_label)}')
# Out:
# Number of testing images: 200
# Number of testing labels: 200

# %%
# Utils pour visualiser les images
from PIL import Image 

def load_img(file_path):
    return Image.open(file_path)

def load_label(file_path):
    # In grayscale (1 canal)
    return Image.open(file_path).convert('L')

# %% [markdown]
# ## Dataloader test

# %%
import torchvision.transforms as transforms

from src.dataset.dataset import VesselDataset

from torch.utils.data import DataLoader



# Paramètres depuis la config

patch_size = config['data'].get('patch_size', 512)

use_patches = config['data'].get('use_patches', True)



image_transform = transforms.Compose([

    transforms.ToTensor(),

])



label_transform = transforms.Compose([

    transforms.ToTensor(),

])



# Nombre d'images à tester (ajuster selon besoin)

nb_images_to_test = 200



test_dataset = VesselDataset(

    test_img[:nb_images_to_test],

    test_label[:nb_images_to_test],

    image_transform=image_transform,

    label_transform=label_transform,

    use_patches=use_patches,

    patch_size=patch_size,

    return_metadata=True,

 )

test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)



print(f"Test dataset patchifié: {len(test_dataset)} imagettes (issues de {nb_images_to_test} images max)")
# Out:
# Test dataset patchifié: 3200 imagettes (issues de 200 images max)

# %% [markdown]
# ## Chargement

# %%
import torch
from src.utils.resume_training import load_previous_model

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Chemin du modèle à charger (utilise le chemin de la config ou un chemin personnalisé)
model_path = config['training']['resume_model_path']

model = load_previous_model(
    path=model_path,
    in_channels=config['model']['in_channels'],
    out_channels=config['model']['out_channels'],
    device=device
)
# Out:
# Device: cuda
# Modèle chargé depuis: ../saved_models/train_20260305-160441/best_model.pth

# %% [markdown]
# ## Prédictions

# %%
from src.models.predict import predict



preds, f1_scores = predict(model, test_loader, device)

print(f"Prédictions reconstruites: {len(preds)} images")

print(f"Mean F1 score (image): {np.mean(f1_scores):.4f}")
# Out:
#   1%|▏         | 44/3200 [00:10<10:56,  4.81it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#   2%|▏         | 48/3200 [00:11<10:55,  4.81it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#   2%|▏         | 56/3200 [00:12<10:32,  4.97it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  58%|█████▊    | 1855/3200 [07:43<05:12,  4.31it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  82%|████████▏ | 2611/3200 [11:04<02:22,  4.12it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  82%|████████▏ | 2612/3200 [11:04<02:18,  4.23it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  82%|████████▏ | 2616/3200 [11:05<02:18,  4.20it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  82%|████████▏ | 2617/3200 [11:06<02:17,  4.25it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  82%|████████▏ | 2620/3200 [11:06<02:15,  4.27it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  87%|████████▋ | 2790/3200 [11:51<01:44,  3.92it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  87%|████████▋ | 2799/3200 [11:53<01:47,  3.73it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  93%|█████████▎| 2979/3200 [12:41<00:54,  4.05it/s]/home/msaunier/Documents/ITI5/MIA/MIA-eyes-vessel-segmentation/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 100%|██████████| 3200/3200 [13:38<00:00,  3.91it/s]
# Prédictions reconstruites: 200 images
# Mean F1 score (image): 0.1755

# %% [markdown]
# ## Visualisation

# %%
# Affichage d'une prédiction
idx = 0

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Image originale
axes[0].imshow(load_img(test_img[idx]))
axes[0].set_title('Image originale')
axes[0].axis('off')

# Ground truth
axes[1].imshow(load_label(test_label[idx]), cmap='gray')
axes[1].set_title('Ground truth')
axes[1].axis('off')

# Prédiction
pred = preds[idx].to('cpu').squeeze().detach().numpy()
print(f"Prédiction shape: {pred.shape}, min: {pred.min()}, max: {pred.max()}")
axes[2].imshow(pred, cmap='gray')
axes[2].set_title('Prédiction')
axes[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Prédiction shape: (2048, 2048), min: False, max: True

# %%
# Affichage de plusieurs prédictions
def visualize_predictions(test_imgs, test_labels, predictions, indices=[0, 1, 2, 3]):
    n = len(indices)
    fig, axes = plt.subplots(n, 3, figsize=(15, 5 * n))
    
    for i, idx in enumerate(indices):
        if idx >= len(predictions):
            continue
            
        # Image originale
        axes[i, 0].imshow(load_img(test_imgs[idx]))
        axes[i, 0].set_title(f'Image {idx}')
        axes[i, 0].axis('off')

        # Ground truth
        axes[i, 1].imshow(load_label(test_labels[idx]), cmap='gray')
        axes[i, 1].set_title('Ground truth')
        axes[i, 1].axis('off')

        # Prédiction
        pred = predictions[idx].to('cpu').squeeze().detach().numpy()
        axes[i, 2].imshow(pred, cmap='gray')
        axes[i, 2].set_title('Prédiction')
        axes[i, 2].axis('off')

    plt.tight_layout()
    plt.show()

# 4 premières
visualize_predictions(test_img, test_label, preds, indices=[0, 1, 2, 3])
