# %% [markdown]
# # Mini notebook pour ouvrir les checkpoints et regarder les détails du modèle

# %%
import os
# Bibliothèque pour lire des .pth
import torch

save_dir = "../saved_models/train_20260305-160441"
checkpoint_path = os.path.join(save_dir, "checkpoint.pth")
checkpoint = torch.load(checkpoint_path)
print(checkpoint.keys())
# Out:
# dict_keys(['model_state_dict', 'optimizer_state_dict', 'train_losses', 'val_losses', 'loss_name'])

# %%
print(len(checkpoint["train_losses"]))
print(checkpoint["loss_name"])
# Out:
# 10
# DICE_BCE_Loss

# %%
model_path = os.path.join(save_dir, "best_model.pth")
print(torch.load(model_path).keys())
# Out:
# odict_keys(['cont1.layers.0.weight', 'cont1.layers.1.weight', 'cont1.layers.1.bias', 'cont1.layers.1.running_mean', 'cont1.layers.1.running_var', 'cont1.layers.1.num_batches_tracked', 'cont1.layers.4.weight', 'cont1.layers.5.weight', 'cont1.layers.5.bias', 'cont1.layers.5.running_mean', 'cont1.layers.5.running_var', 'cont1.layers.5.num_batches_tracked', 'cont2.layers.0.weight', 'cont2.layers.1.weight', 'cont2.layers.1.bias', 'cont2.layers.1.running_mean', 'cont2.layers.1.running_var', 'cont2.layers.1.num_batches_tracked', 'cont2.layers.4.weight', 'cont2.layers.5.weight', 'cont2.layers.5.bias', 'cont2.layers.5.running_mean', 'cont2.layers.5.running_var', 'cont2.layers.5.num_batches_tracked', 'cont3.layers.0.weight', 'cont3.layers.1.weight', 'cont3.layers.1.bias', 'cont3.layers.1.running_mean', 'cont3.layers.1.running_var', 'cont3.layers.1.num_batches_tracked', 'cont3.layers.4.weight', 'cont3.layers.5.weight', 'cont3.layers.5.bias', 'cont3.layers.5.running_mean', 'cont3.layers.5.running_var', 'cont3.layers.5.num_batches_tracked', 'cont4.layers.0.weight', 'cont4.layers.1.weight', 'cont4.layers.1.bias', 'cont4.layers.1.running_mean', 'cont4.layers.1.running_var', 'cont4.layers.1.num_batches_tracked', 'cont4.layers.4.weight', 'cont4.layers.5.weight', 'cont4.layers.5.bias', 'cont4.layers.5.running_mean', 'cont4.layers.5.running_var', 'cont4.layers.5.num_batches_tracked', 'cont5.layers.0.weight', 'cont5.layers.1.weight', 'cont5.layers.1.bias', 'cont5.layers.1.running_mean', 'cont5.layers.1.running_var', 'cont5.layers.1.num_batches_tracked', 'cont5.layers.4.weight', 'cont5.layers.5.weight', 'cont5.layers.5.bias', 'cont5.layers.5.running_mean', 'cont5.layers.5.running_var', 'cont5.layers.5.num_batches_tracked', 'exp1.layers.0.weight', 'exp1.layers.1.weight', 'exp1.layers.1.bias', 'exp1.layers.1.running_mean', 'exp1.layers.1.running_var', 'exp1.layers.1.num_batches_tracked', 'exp1.layers.3.weight', 'exp1.layers.4.weight', 'exp1.layers.4.bias', 'exp1.layers.4.running_mean', 'exp1.layers.4.running_var', 'exp1.layers.4.num_batches_tracked', 'exp2.layers.0.weight', 'exp2.layers.1.weight', 'exp2.layers.1.bias', 'exp2.layers.1.running_mean', 'exp2.layers.1.running_var', 'exp2.layers.1.num_batches_tracked', 'exp2.layers.3.weight', 'exp2.layers.4.weight', 'exp2.layers.4.bias', 'exp2.layers.4.running_mean', 'exp2.layers.4.running_var', 'exp2.layers.4.num_batches_tracked', 'exp3.layers.0.weight', 'exp3.layers.1.weight', 'exp3.layers.1.bias', 'exp3.layers.1.running_mean', 'exp3.layers.1.running_var', 'exp3.layers.1.num_batches_tracked', 'exp3.layers.3.weight', 'exp3.layers.4.weight', 'exp3.layers.4.bias', 'exp3.layers.4.running_mean', 'exp3.layers.4.running_var', 'exp3.layers.4.num_batches_tracked', 'exp4.layers.0.weight', 'exp4.layers.1.weight', 'exp4.layers.1.bias', 'exp4.layers.1.running_mean', 'exp4.layers.1.running_var', 'exp4.layers.1.num_batches_tracked', 'exp4.layers.3.weight', 'exp4.layers.4.weight', 'exp4.layers.4.bias', 'exp4.layers.4.running_mean', 'exp4.layers.4.running_var', 'exp4.layers.4.num_batches_tracked', 'out.conv.weight', 'out.conv.bias'])
